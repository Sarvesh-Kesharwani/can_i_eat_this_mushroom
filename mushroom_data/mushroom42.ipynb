# %%
https://www.kaggle.com/datasets/ranitsarkar01/porter-delivery-time-estimation
# Out:
#   Cell In[2], line 1
#     https://www.kaggle.com/datasets/ranitsarkar01/porter-delivery-time-estimation
#           ^
# SyntaxError: invalid syntax

# %%
! pip install pandas

# %%
import pandas as pd
import pprint

# %%
data = pd.read_csv('G:\Github_Projects\can_i_eat_this_mushroom\Mushroom_Dataset.csv')
data.head(10)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# <>:1: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\sarve\AppData\Local\Temp\ipykernel_13920\1266499060.py:1: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('G:\Github_Projects\can_i_eat_this_mushroom\Mushroom_Dataset.csv')
#   class  cap-diameter cap-shape cap-surface cap-color does-bruise-or-bleed  \
# 0     p         15.26         x           g         o                    f
# 1     p         16.60         x           g         o                    f
# 2     p         14.07         x           g         o                    f
# 3     p         14.17         f           h         e                    f
# 4     p         14.64         x           h         o                    f
# 5     p         15.34         x           g         o                    f
# 6     p         14.85         f           h         o                    f
# ...

# %%
data.tail(10)
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 61059     p          1.15         f           s         y
# 61060     p          1.13         x           s         y
# 61061     p          1.25         x           s         y
# 61062     p          1.25         s           s         y
# 61063     p          1.42         x           s         y
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 61059                    f               f            f          f
# 61060                    f               f            f          f
# 61061                    f               f            f          f
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61069 entries, 0 to 61068
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   class                 61069 non-null  object
#  1   cap-diameter          61069 non-null  float64
#  2   cap-shape             61069 non-null  object
#  3   cap-surface           46949 non-null  object
#  4   cap-color             61069 non-null  object
#  5   does-bruise-or-bleed  61069 non-null  object
#  6   gill-attachment       51185 non-null  object
#  7   gill-spacing          36006 non-null  object
#  8   gill-color            61069 non-null  object
#  9   stem-height           61069 non-null  float64
#  10  stem-width            61069 non-null  float64
#  11  stem-root             9531 non-null   object
#  12  stem-surface          22945 non-null  object
#  13  stem-color            61069 non-null  object
#  14  veil-type             3177 non-null   object
# ...

# %%
len(data)
# Out:
# 61069

# %%
data.isnull().sum()/len(data)
# Out:
# class                   0.000000
# cap-diameter            0.000000
# cap-shape               0.000000
# cap-surface             0.231214
# cap-color               0.000000
# does-bruise-or-bleed    0.000000
# gill-attachment         0.161850
# gill-spacing            0.410405
# gill-color              0.000000
# stem-height             0.000000
# stem-width              0.000000
# stem-root               0.843931
# stem-surface            0.624277
# stem-color              0.000000
# veil-type               0.947977
# veil-color              0.878613
# has-ring                0.000000
# ring-type               0.040462
# spore-print-color       0.895954
# habitat                 0.000000
# season                  0.000000
# dtype: float64

# %%
data1 = data.drop(['veil-type', 'veil-color', 'spore-print-color', 'stem-root'], axis=1)
data1
# Out:
#       class  cap-diameter cap-shape cap-surface cap-color  \
# 0         p         15.26         x           g         o
# 1         p         16.60         x           g         o
# 2         p         14.07         x           g         o
# 3         p         14.17         f           h         e
# 4         p         14.64         x           h         o
# ...     ...           ...       ...         ...       ...
# 61064     p          1.18         s           s         y
# 61065     p          1.27         f           s         y
# 61066     p          1.27         s           s         y
# 61067     p          1.24         f           s         y
# 61068     p          1.17         s           s         y
#
#       does-bruise-or-bleed gill-attachment gill-spacing gill-color  \
# 0                        f               e          NaN          w
# 1                        f               e          NaN          w
# ...

# %%
data1.isnull().sum()/len(data)
# Out:
# class                   0.000000
# cap-diameter            0.000000
# cap-shape               0.000000
# cap-surface             0.231214
# cap-color               0.000000
# does-bruise-or-bleed    0.000000
# gill-attachment         0.161850
# gill-spacing            0.410405
# gill-color              0.000000
# stem-height             0.000000
# stem-width              0.000000
# stem-surface            0.624277
# stem-color              0.000000
# has-ring                0.000000
# ring-type               0.040462
# habitat                 0.000000
# season                  0.000000
# dtype: float64

# %%
data['cap-diameter'].value_counts()
# Out:
# cap-diameter
# 3.18     103
# 3.14      98
# 3.13      96
# 3.85      95
# 3.25      95
#         ...
# 51.39      1
# 47.85      1
# 50.18      1
# 45.67      1
# 20.42      1
# Name: count, Length: 2571, dtype: int64

# %%
data['cap-diameter'].isnull().sum()
# Out:
# 0

# %%
plt.hist(data['cap-diameter'])
plt.show()

# %%
data.describe()
# Out:
#        cap-diameter   stem-height    stem-width
# count  61069.000000  61069.000000  61069.000000
# mean       6.733854      6.581538     12.149410
# std        5.264845      3.370017     10.035955
# min        0.380000      0.000000      0.000000
# 25%        3.480000      4.640000      5.210000
# 50%        5.860000      5.950000     10.190000
# 75%        8.540000      7.740000     16.570000
# max       62.340000     33.920000    103.910000

# %%
from matplotlib import pyplot as plt

# %%
plt.scatter(data['cap-diameter'], data['stem-width'])
plt.show()

# %%
data.isnull().sum()
# Out:
# class                       0
# cap-diameter                0
# cap-shape                   0
# cap-surface             14120
# cap-color                   0
# does-bruise-or-bleed        0
# gill-attachment          9884
# gill-spacing            25063
# gill-color                  0
# stem-height                 0
# stem-width                  0
# stem-root               51538
# stem-surface            38124
# stem-color                  0
# veil-type               57892
# veil-color              53656
# has-ring                    0
# ring-type                2471
# spore-print-color       54715
# habitat                     0
# season                      0
# dtype: int64

# %%
! pip install missingno
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/60.4 kB 325.1 kB/s eta 0:00:01
#      -------------------------------- ----- 51.2/60.4 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 60.4/60.4 kB 401.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/45.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/45.8 MB 2.2 MB/s eta 0:00:21
#    ---------------------------------------- 0.4/45.8 MB 4.2 MB/s eta 0:00:11
#     --------------------------------------- 1.0/45.8 MB 6.9 MB/s eta 0:00:07
#    - -------------------------------------- 2.1/45.8 MB 11.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.2/45.8 MB 21.9 MB/s eta 0:00:02
#    -------- ------------------------------- 9.7/45.8 MB 34.5 MB/s eta 0:00:02
# ...

# %%
import missingno as mgno

# %%
mgno.matrix(data)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data.corr()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
! pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
X = [1,5,9,0] 
Y = [3,0,2,9]

x = set(X)
y = set(Y)

x.intersection(y)
# Out:
# {0, 9}

# %%
x = [1,2,3,1,3,6,5]
out = set()
duplicates = []
for i in x:
    len_out = len(out)
    out.add(i)
    if len(out) <= len_out:
        duplicates.append(i)
print(duplicates)
# Out:
# [1, 3]
