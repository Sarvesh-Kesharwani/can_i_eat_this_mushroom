# %%
import pandas as pd

data = pd.read_csv('G:\Github_Projects\can_i_eat_this_mushroom\coupon_data.csv')
data.head()
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# <>:3: SyntaxWarning: invalid escape sequence '\G'
# C:\Users\sarve\AppData\Local\Temp\ipykernel_4208\3546196087.py:3: SyntaxWarning: invalid escape sequence '\G'
#   data = pd.read_csv('G:\Github_Projects\can_i_eat_this_mushroom\coupon_data.csv')
#        destination  passanger weather  temperature                 coupon  \
# 0  No Urgent Place      Alone   Sunny           55        Restaurant(<20)
# 1  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 2  No Urgent Place  Friend(s)   Sunny           80  Carry out & Take away
# 3  No Urgent Place  Friend(s)   Sunny           80           Coffee House
# 4  No Urgent Place  Friend(s)   Sunny           80           Coffee House
#
#   expiration  gender age      maritalStatus  has_children  ... CoffeeHouse  \
# 0         1d  Female  21  Unmarried partner             1  ...       never
# 1         2h  Female  21  Unmarried partner             1  ...       never
# ...

# %%
type(data.columns[0])
# Out:
# str

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12684 entries, 0 to 12683
# Data columns (total 25 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   destination           12684 non-null  object
#  1   passanger             12684 non-null  object
#  2   weather               12684 non-null  object
#  3   temperature           12684 non-null  int64
#  4   coupon                12684 non-null  object
#  5   expiration            12684 non-null  object
#  6   gender                12684 non-null  object
#  7   age                   12684 non-null  object
#  8   maritalStatus         12684 non-null  object
#  9   has_children          12684 non-null  int64
#  10  education             12684 non-null  object
#  11  occupation            12684 non-null  object
#  12  income                12684 non-null  object
#  13  car                   108 non-null    object
#  14  Bar                   12577 non-null  object
# ...

# %%
import seaborn as sns

# %%
sns.histplot(data['direction_opp'])
# Out:
# <Axes: xlabel='direction_opp', ylabel='Count'>

# %%
data['direction_opp'].value_counts()
# Out:
# direction_opp
# 1    9960
# 0    2724
# Name: count, dtype: int64

# %%
sns.barplot(data['direction_opp'])
# Out:
# <Axes: ylabel='direction_opp'>

# %%
data.columns
# Out:
# Index(['destination', 'passanger', 'weather', 'temperature', 'coupon',
#        'expiration', 'gender', 'age', 'maritalStatus', 'has_children',
#        'education', 'occupation', 'income', 'car', 'Bar', 'CoffeeHouse',
#        'CarryAway', 'RestaurantLessThan20', 'Restaurant20To50',
#        'toCoupon_GEQ5min', 'toCoupon_GEQ15min', 'toCoupon_GEQ25min',
#        'direction_same', 'direction_opp', 'Accept(Y/N?)'],
#       dtype='object')

# %%
data['destination'].value_counts()
# Out:
# destination
# No Urgent Place    6283
# Home               3237
# Work               3164
# Name: count, dtype: int64

# %%
data['passanger'].value_counts()
# Out:
# passanger
# Alone        7305
# Friend(s)    3298
# Partner      1075
# Kid(s)       1006
# Name: count, dtype: int64

# %%
data['weather'].value_counts()
# Out:
# weather
# Sunny    10069
# Snowy     1405
# Rainy     1210
# Name: count, dtype: int64

# %%
data['temperature'].value_counts()
# Out:
# temperature
# 80    6528
# 55    3840
# 30    2316
# Name: count, dtype: int64

# %%
data['coupon'].value_counts()
# Out:
# coupon
# Coffee House             3996
# Restaurant(<20)          2786
# Carry out & Take away    2393
# Bar                      2017
# Restaurant(20-50)        1492
# Name: count, dtype: int64

# %%
data['expiration'].value_counts()
# Out:
# expiration
# 1d    7091
# 2h    5593
# Name: count, dtype: int64

# %%
data['gender'].value_counts()
# Out:
# gender
# Female    6511
# Male      6173
# Name: count, dtype: int64

# %%
data['age'].value_counts()
# Out:
# age
# 21         2653
# 26         2559
# 31         2039
# 50plus     1788
# 36         1319
# 41         1093
# 46          686
# below21     547
# Name: count, dtype: int64

# %%
data['maritalStatus'].value_counts()
# Out:
# maritalStatus
# Married partner      5100
# Single               4752
# Unmarried partner    2186
# Divorced              516
# Widowed               130
# Name: count, dtype: int64

# %%
type(data['maritalStatus'].value_counts())
# Out:
# pandas.core.series.Series

# %%
list(data['maritalStatus'].value_counts())
# Out:
# [5100, 4752, 2186, 516, 130]

# %%
import seaborn as sns

sns.countplot(data, width=0.5, legend='brief', x='maritalStatus') # , order=sorted(list(data['maritalStatus'].value_counts()))
# Out:
# <Axes: xlabel='maritalStatus', ylabel='count'>

# %%
sns.pairplot(data)

# %%
sns.countplot(data,x='age', order=sorted(set(data['age'])))
# Out:
# <Axes: xlabel='age', ylabel='count'>
